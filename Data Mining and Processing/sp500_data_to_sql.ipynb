# %% [markdown]
# ## Gather Company Info
# Other code in this repository gathers OHLC data and calculates the value of portfolio holdings at different dates. However, to balance a portfolio, we need to also know information about each company, such as its sector and industry.
#
# The following code pulls the unique holdings currently in the portfolio, obtains basic information for each company, and writes this data to a SQL database.

# %%
# necessary when running from jupyter lab o.g. docker image
# !pip install sqlalchemy_utils psycopg2-binary yfinance

# %%
import pandas as pd
import numpy as np
from datetime import date
import yfinance as yf

from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# connect to Docker SQL database
#engine = create_engine('postgresql+psycopg2://postgres:########@###.###.##.##:54320/finance')

# %% [markdown]
# #### Get a list of the S&P 500 companies

# %%
import bs4 as bs
import pickle
import requests

def getSP500():
    resp = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        tickers.append(ticker)
        
    with open("sp500tickers.pickle","wb") as f:
        pickle.dump(tickers,f)
        
    return tickers

sp = getSP500()

# initialize character 
char = '\n'
  
# Remove character from Strings list 
# using list comprehension + replace() 
sp = [ele.replace(char, '') for ele in sp] 

# fix Berkshire and others (can't read the period, needs the hyphen)
for i in sp:
    sp = [i.replace('.','-') for i in sp]
    
# find problematic strings
matching = [s for s in sp if "-" in s]

# remove the problems
for i in matching:
    sp.remove(i) 

# check what is returned
sp[0:20]
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE']

# %% [markdown]
# #### Get a list of equities in the portfolio

# %%
# read Postgresql data into python as Pandas df
stocks = pd.read_sql_table(table_name = 'equities', schema='public', con=engine)
portfolio = list(stocks['ticker'])
portfolio[0:20]
# Out:
# ['AAPL',
#  'ABBV',
#  'ADM',
#  'AFL',
#  'AFRM',
#  'AQN',
#  'BABA',
#  'BRK-B',
#  'BX',
#  'CAG',
#  'CASY',
#  'CHRW',
#  'CMI',
#  'COST',
#  'CTVA',
#  'CURLF',
#  'CVNA',
#  'DG',
#  'ELY',
#  'ETSY']

# %%
# get list of unique equity symbols in either the S&P 500 or our portfolio
# https://stackoverflow.com/questions/28444561/get-only-unique-elements-from-two-lists
symbols_list = list(set(sp).symmetric_difference(set(portfolio)))
symbols_list.sort()
symbols_list[0:20]
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFRM',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB']

# %%
# pull existing SQL db, compare with current list of holdings, make list of just those that are new to add to info db
missing_tickers = pd.read_sql("SELECT ticker AS missing \
FROM public.equities \
EXCEPT SELECT symbol AS missing \
FROM public.equity_info", con = engine)
missing_tickers = list(missing_tickers['missing'])
missing_tickers
# Out:
# ['PPG', 'CASY']

# %% [markdown]
# #### Get basic info for each company and save to SQL

# %%
def yahooInfo(symbols_list):

    # start with empty dataframe
    info_df = pd.DataFrame()
    
    # grab Yahoo info on each company
    for i in symbols_list:
            try:
                df = pd.DataFrame.from_dict(yf.Ticker(i).info, orient='index').T
                df = df.set_index('symbol')

                # full join to avoid pesky issues with columns not alwasy matching
                info_df = pd.concat([info_df, df]) 
    
            except:
                print('Error obtaining info for ' + str(i))
                pass
            
    # reduce to only columns of interest
    info_cols = ['shortName','longName','exchange','market','sector','industry','quoteType','longBusinessSummary','country','city','state','zip']
    info_df = info_df[info_cols]
            
    return info_df

# %%
df = yahooInfo(missing_tickers)
df
# Out:
#                           shortName                      longName exchange  \
# symbol
# PPG            PPG Industries, Inc.          PPG Industries, Inc.      NYQ
# CASY    Caseys General Stores, Inc.  Casey's General Stores, Inc.      NMS
#
#            market              sector             industry quoteType  \
# symbol
# PPG     us_market     Basic Materials  Specialty Chemicals    EQUITY
# CASY    us_market  Consumer Defensive       Grocery Stores    EQUITY
#
#                                       longBusinessSummary        country  \
# symbol
# PPG     PPG Industries, Inc. manufactures and distribu...  United States
# CASY    Casey's General Stores, Inc., together with it...  United States
#
#               city state    zip
# symbol
# PPG     Pittsburgh    PA  15272
# CASY        Ankeny    IA  50021

# %%
# when finished, print the data to sql database
df.to_sql(name = 'equity_info', schema = 'public', con=engine, if_exists='append')

# %%
# check if it worked
pd.read_sql_table(table_name = 'equity_info', schema='public', con=engine)
# Out:
#    symbol                       shortName                        longName  \
# 0    AAPL                      Apple Inc.                      Apple Inc.
# 1    ABBV                     AbbVie Inc.                     AbbVie Inc.
# 2     ADM  Archer-Daniels-Midland Company  Archer-Daniels-Midland Company
# 3     AFL              AFLAC Incorporated              Aflac Incorporated
# 4    AFRM           Affirm Holdings, Inc.           Affirm Holdings, Inc.
# ..    ...                             ...                             ...
# 73     WM          Waste Management, Inc.          Waste Management, Inc.
# 74    WMT                    Walmart Inc.                    Walmart Inc.
# 75    XYL                      Xylem Inc.                      Xylem Inc.
# 76    PPG            PPG Industries, Inc.            PPG Industries, Inc.
# 77   CASY     Caseys General Stores, Inc.    Casey's General Stores, Inc.
#
#    exchange     market              sector                         industry  \
# 0       NMS  us_market          Technology             Consumer Electronics
# 1       NYQ  us_market          Healthcare       Drug Manufacturers—General
# 2       NYQ  us_market  Consumer Defensive                    Farm Products
# 3       NYQ  us_market  Financial Services                   Insurance—Life
# 4       NMS  us_market          Technology  Information Technology Services
# ..      ...        ...                 ...                              ...
# 73      NYQ  us_market         Industrials                 Waste Management
# 74      NYQ  us_market  Consumer Defensive                  Discount Stores
# 75      NYQ  us_market         Industrials   Specialty Industrial Machinery
# 76      NYQ  us_market     Basic Materials              Specialty Chemicals
# 77      NMS  us_market  Consumer Defensive                   Grocery Stores
#
#    quoteType                                longBusinessSummary  \
# 0     EQUITY  Apple Inc. designs, manufactures, and markets ...
# 1     EQUITY  AbbVie Inc. discovers, develops, manufactures,...
# 2     EQUITY  Archer-Daniels-Midland Company procures, trans...
# 3     EQUITY  Aflac Incorporated, through its subsidiaries, ...
# 4     EQUITY  Affirm Holdings, Inc. operates a platform for ...
# ..       ...                                                ...
# 73    EQUITY  Waste Management, Inc., through its subsidiari...
# 74    EQUITY  Walmart Inc. engages in the operation of retai...
# 75    EQUITY  Xylem Inc., together with its subsidiaries, en...
# 76    EQUITY  PPG Industries, Inc. manufactures and distribu...
# 77    EQUITY  Casey's General Stores, Inc., together with it...
#
#           country           city state         zip
# 0   United States      Cupertino    CA       95014
# 1   United States  North Chicago    IL  60064-6400
# 2   United States        Chicago    IL       60601
# 3   United States       Columbus    GA       31999
# 4   United States  San Francisco    CA  94108-2716
# ..            ...            ...   ...         ...
# 73  United States        Houston    TX       77002
# 74  United States    Bentonville    AR       72716
# 75  United States      Rye Brook    NY       10573
# 76  United States     Pittsburgh    PA       15272
# 77  United States         Ankeny    IA       50021
#
# [78 rows x 13 columns]
